# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank65536/cvdev/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Preprocessing
#
#
#
# Here we have two kinds of reefs. The first one is elkhorn coral reef  and the second one is staghorn reef. Each of the reefs have around 300 images.
# In this data preprocessing section we have displayed the differnt kinds of reefs and data augmentation is also done in order to increas
#
# ```
# # This is formatted as code
# ```
#
# e the size of the dataset.

# %%
import cv2
from matplotlib import pyplot as plt
import PIL
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir('/content/gdrive/My Drive/coral_dataset/elkhorn_cropped')

# %%
img = cv2.imread("/content/gdrive/My Drive/coral_dataset/elkhorn_cropped/elkhorn-1-3-13.jpg")
plt.imshow(img)
img1 = PIL.Image.open("/content/gdrive/My Drive/coral_dataset/elkhorn_cropped/elkhorn-1-3-13.jpg")
width,ht,c = img.shape
print(width,ht)
# Out:
# 2048 2048

# %%
import os
import numpy as np

base_url = "/content/gdrive/My Drive/coral_dataset/elkhorn_cropped/"
elkhorn_files  = "/content/gdrive/My Drive/coral_dataset/elkhorn_cropped"
elkhorn_names = np.array(os.listdir(elkhorn_files))

print("ELKHORN IMAGES")
for i in range(0,5):
  new_url = base_url + elkhorn_names[i]
  temp_img = cv2.imread(new_url)
  plt.imshow(temp_img)
  plt.show()

staghorn_files = "/content/gdrive/My Drive/coral_dataset/staghorn_cropped/"
staghorn_names = np.array(os.listdir(staghorn_files))

print("STAGHORN IMAGES")
for i in range(0,5):
  new_url = staghorn_files + staghorn_names[i]
  temp_img = cv2.imread(new_url)
  plt.imshow(temp_img)
  plt.show()
# Out:
# ELKHORN IMAGES
# STAGHORN IMAGES
# /content/gdrive/My Drive/coral_dataset/staghorn_cropped/staghorn-1-5-3.jpg
# /content/gdrive/My Drive/coral_dataset/staghorn_cropped/staghorn-1-5-4.jpg
# /content/gdrive/My Drive/coral_dataset/staghorn_cropped/staghorn-1-4-4.jpg
# /content/gdrive/My Drive/coral_dataset/staghorn_cropped/staghorn-1-4-3.jpg
# /content/gdrive/My Drive/coral_dataset/staghorn_cropped/staghorn-1-3-4.jpg

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import img_to_array,array_to_img,load_img
datagen = ImageDataGenerator(
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
print(type(datagen))

x = img_to_array(img)
# Reshaping the input image
x = x.reshape((1, ) + x.shape) 

# Generating and saving 5 augmented samples 
# using the above defined parameters.
k = np.array([img]) 
link = "/content/gdrive/My Drive/coral_dataset/elkhorn_cropped/elkhorn-1-3-13.jpg"
#k = datagen.flow(k, batch_size = 1,save_to_dir ='/content/gdrive/My Drive/coral_dataset',save_prefix ='image', save_format ='jpg')
i = 0
for batch in datagen.flow(k, batch_size = 1,save_to_dir ='/content/gdrive/My Drive/coral_dataset/augmented_images',save_prefix ='image', save_format ='jpg'):
  i += 1
  if i > 5:
    break
    


print("Augmented Images")
base_url = "/content/gdrive/My Drive/coral_dataset/augmented_images/"
aug_images_names = np.array(os.listdir(base_url))

for i in range(0,5):
  new_url = base_url + aug_images_names[i]
  temp_img = cv2.imread(new_url)
  plt.imshow(temp_img)
  plt.show()
# Out:
# <class 'keras.preprocessing.image.ImageDataGenerator'>
# Augmented Images
